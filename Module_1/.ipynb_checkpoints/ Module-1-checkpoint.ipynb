# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.linear_model import Ridge

# %%
mean = 0
sigma = 0.3

x_wrong = np.random.uniform(0,1,10)
#x2 = np.linspace(0, 1, 100)
#x_data = np.sort(x1)

def data_wrong(x): ##the reason maybe data_wrong function does not interpreting x as an array. So it 
    f = np.sin(2*np.pi*x) + np.random.normal(loc=0, scale=0.3)
    return f


y_wrong = data_wrong(x_wrong)

plt.scatter(x_wrong, y_wrong)
plt.show()

# %%
def data(N):
    x1 = np.random.uniform(size=N)
    f = np.sin(2*np.pi*x1) + np.random.normal(loc=0, scale=0.3, size=N)
    return x1, f

x_correct, f_correct = data(1000)
plt.scatter(x_correct, f_correct)
plt.show()

# %%
def polynomial1(x, poly):
    result = 0
    for coeff in poly:
        result = x * result + coeff
    return result

deg = 9
c_correct = np.polyfit(x_correct, f_correct, deg)
c_wrong = np.polyfit(x_wrong, y_wrong, deg)

# %%
x_even_wrong = np.linspace(x_wrong.min(), x_wrong.max(), 500)
plt.plot(x_even_wrong, polynomial1(x_even_wrong, c_wrong))
plt.scatter(x_wrong, y_wrong)
plt.show()

# %%
x_even_correct = np.linspace(x_correct.min(), x_correct.max(), 500)
plt.plot(x_even_correct, polynomial1(x_even_correct, c_correct))
plt.scatter(x_correct, f_correct)
plt.show()

# %%
deg = 9
#c = np.polyfit(x, f, deg)
#len(c)
polynomial = np.poly1d(c_correct)
x_even_correct = np.linspace(x_correct.min(), x_correct.max(), 500)
plt.plot(x_even_correct, polynomial(x_even_correct))
plt.scatter(x_correct, f_correct)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
deviation1 = (polynomial1(x_correct, c_correct) - f_correct)**2
#print(deviation1)
deviation2 = (polynomial(x_correct) - f_correct)**2
E_rms1 = (np.sum(deviation1)/len(x_correct))**0.5
E_rms2 = (np.sum(deviation2)/len(x_correct))**0.5
#print(deviation2)
#print(polynomial1(x_correct, c_correct))
#print(polynomial(x_correct))
print(E_rms1, E_rms2)
# Out:
# 0.2958502927740531 0.2958502927740531

# %%
plt.scatter(x_correct, polynomial1(x_correct, c_correct))
plt.scatter(x_correct, polynomial(x_correct))
plt.show()
